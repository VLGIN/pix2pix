# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)

import os
os.chdir("/content/drive/MyDrive/pix2pix")
# Out:
# Mounted at /content/drive

# %%
# !pip install -r requirements.txt

# %%
# !python train.py --dataroot ./facades --name facades_pix2pix --model pix2pix --direction BtoA --norm batch --pool_size 0 --use_wandb --netG 'unet_256' --lambda_L1 0.5 --save_epoch_freq 20 --netD pixel
